# %% [markdown]
# # ARIMA and seasonal ARIMA

# %% [markdown]
# ### Autoregressive integrated moving averages-
# The general pupose of these type of models are: <br/>
# . Visualize the time series data <br/>
# . Make the time series data stationary <br/>
# . Plot the correlation and auto correlation charts <br/>
# . Construct ARIMA or seasonal ARIMA based on the data <br/>
# . Use the model to make predictions

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("dataset.csv")

# %%
df
# Out:
#             Date  Temp
# 0     1981-01-01  20.7
# 1     1981-01-02  17.9
# 2     1981-01-03  18.8
# 3     1981-01-04  14.6
# 4     1981-01-05  15.8
# ...          ...   ...
# 3645  1990-12-27  14.0
# 3646  1990-12-28  13.6
# 3647  1990-12-29  13.5
# 3648  1990-12-30  15.7
# 3649  1990-12-31  13.0
#
# [3650 rows x 2 columns]

# %%
df[df['Date'].isnull() == True]
# Out:
# Empty DataFrame
# Columns: [Date, Temp]
# Index: []

# %%
df[df['Temp'].isnull() == True]
# Out:
# Empty DataFrame
# Columns: [Date, Temp]
# Index: []

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.set_index('Date',inplace=True)

# %%
df.describe()
# Out:
#               Temp
# count  3650.000000
# mean     11.177753
# std       4.071837
# min       0.000000
# 25%       8.300000
# 50%      11.000000
# 75%      14.000000
# max      26.300000

# %% [markdown]
# # Visualizing the Data

# %%
df.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# testing for stationary
# Augomented dickey fuller test used to check if change in series data is stationary or not 
# No constant, no trend: Δyt = γyt-1 + vt
# Constant, no trend: Δyt = α + γyt-1 + vt
# Constant and trend: Δyt = α + γyt-1 + λt + vt
from statsmodels.tsa.stattools import adfuller
test_result = adfuller(df['Temp'])

# %%
#Ho: It is non stationary Ho indicates γ is less than 1
#H1: It is stationary H1 indicates γ is = 0
def adfuller_test(temperature):
    result = adfuller(temperature)
    labels = ['ADF Test Statistic','p-value','#Lags Used','Number of Observations Used']
    for value, label in zip(result,labels):
        print(label+' : '+str(value) )
    if result[1] <= 0.05:
        print("strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data has no unit root and is stationary")
    else:
        print("weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary ")

# %%
adfuller_test(df['Temp'])
# Out:
# ADF Test Statistic : -4.444804924611678
# p-value : 0.00024708263003612134
# #Lags Used : 20
# Number of Observations Used : 3629
# strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data has no unit root and is stationary

# %%
df1 = pd.read_csv("dataset1.csv")

# %%
df1
# Out:
#         Month  Sunspots
# 0     1749-01      58.0
# 1     1749-02      62.6
# 2     1749-03      70.0
# 3     1749-04      55.7
# 4     1749-05      85.0
# ...       ...       ...
# 2815  1983-08      71.8
# 2816  1983-09      50.3
# 2817  1983-10      55.8
# 2818  1983-11      33.3
# 2819  1983-12      33.4
#
# [2820 rows x 2 columns]

# %%
df1[df1['Month'].isnull() == True]
# Out:
# Empty DataFrame
# Columns: [Month, Sunspots]
# Index: []

# %%
df1[df1['Sunspots'].isnull() == True]
# Out:
# Empty DataFrame
# Columns: [Month, Sunspots]
# Index: []

# %%
df1['Month'] = pd.to_datetime(df1['Month'])

# %%
df1.set_index('Month',inplace=True)

# %%
df1.plot()
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
test_result = adfuller(df1['Sunspots'])

# %%
adfuller_test(df1['Sunspots'])
# Out:
# ADF Test Statistic : -9.567667511913076
# p-value : 2.333452143866306e-16
# #Lags Used : 27
# Number of Observations Used : 2792
# strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data has no unit root and is stationary

# %%
df2 = pd.read_csv("perrin-freres-monthly-champagne.csv")

# %%
df2
# Out:
#                                                  Month  \
# 0                                              1964-01
# 1                                              1964-02
# 2                                              1964-03
# 3                                              1964-04
# 4                                              1964-05
# ..                                                 ...
# 102                                            1972-07
# 103                                            1972-08
# 104                                            1972-09
# 105                                                NaN
# 106  Perrin Freres monthly champagne sales millions...
#
#      Perrin Freres monthly champagne sales millions ?64-?72
# 0                                               2815.0
# 1                                               2672.0
# 2                                               2755.0
# 3                                               2721.0
# ...

# %%
df2.columns = ["Month","Sales"]

# %%
df2[df2['Month'].isnull() == True]
# Out:
#     Month  Sales
# 105   NaN    NaN

# %%
df2[df2['Sales'].isnull() == True]
# Out:
#                                                  Month  Sales
# 105                                                NaN    NaN
# 106  Perrin Freres monthly champagne sales millions...    NaN

# %%
df2 = df2[:105][:]

# %%
df2['Month'] = pd.to_datetime(df2['Month'])

# %%
df2.plot()
# Out:
# <AxesSubplot:>

# %%
test_result = adfuller(df2['Sales'])

# %%
adfuller_test(df2['Sales'])
# Out:
# ADF Test Statistic : -1.8335930563276184
# p-value : 0.36391577166024713
# #Lags Used : 11
# Number of Observations Used : 93
# weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary

# %%
# Finally got a non - stationary dataset if the data is already stationary skip the differencing part

# %% [markdown]
# # Differencing

# %%
#if the data is not seasonal
df2['Sales First Difference'] = df2['Sales'] - df2['Sales'].shift(1)

# %%
df2['Seasonal First Difference'] = df2['Sales']-df2['Sales'].shift(12) # approximately 104/8 try for different values in shift

# %%
## Again test dickey fuller test
adfuller_test(df2['Seasonal First Difference'].dropna())
# Out:
# ADF Test Statistic : -7.626619157213164
# p-value : 2.060579696813685e-11
# #Lags Used : 0
# Number of Observations Used : 92
# strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data has no unit root and is stationary

# %%
df2['Seasonal First Difference'].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Auto regressive model

# %%
from pandas.plotting import autocorrelation_plot
autocorrelation_plot(df2['Sales'])
plt.show()

# %% [markdown]
# ## Final Thoughts on Autocorrelation and Partial Autocorrelation
# - Identification of an AR model is often best done with the PACF.
#   - For an AR model, the theoretical PACF “shuts off” past the order of the model. The phrase “shuts off” means that in theory the partial autocorrelations are equal to 0 beyond that point. Put another way, the number of non-zero partial autocorrelations gives the order of the AR model. By the “order of the model” we mean the most extreme lag of x that is used as a predictor.
#   <br/>
# - Identification of an MA model is often best done with the ACF rather than the PACF.
#     - For an MA model, the theoretical PACF does not shut off, but instead tapers toward 0 in some manner. A clearer pattern for an MA model is in the ACF. The ACF will have non-zero autocorrelations only at lags involved in the model.
# <br/><br/>
# p,d,q <br/>
# p AR model lags <br/>
# d differencing <br/>
# q MA lags

# %%
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = plot_acf(df2['Seasonal First Difference'].iloc[13:],lags = 40,ax = ax1) #u can take dropna instead of iloc
ax2 = fig.add_subplot(212)
fig = plot_pacf(df2['Seasonal First Difference'].iloc[13:],lags = 40,ax = ax2)

# %%
# For non-seasonal data
#p=1, d=1(no of sedasonal differcing), q=0or1
from statsmodels.tsa.arima_model import ARIMA

# %%
model = ARIMA(df2['Sales'], order = (1,1,1))
model_fit = model.fit()
# Out:
# c:\users\ameya gupta\miniconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# c:\users\ameya gupta\miniconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# ...

# %%
model_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              ARIMA Model Results
# ...
# Dep. Variable:                D.Sales   No. Observations:                  104
# Model:                 ARIMA(1, 1, 1)   Log Likelihood                -951.126
# Method:                       css-mle   S.D. of innovations           2227.262
# Date:                Mon, 21 Jun 2021   AIC                           1910.251
# Time:                        20:09:31   BIC                           1920.829
# Sample:                             1   HQIC                          1914.536
#
# ...
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            22.7839     12.405      1.837      0.066      -1.530      47.098
# ar.L1.D.Sales     0.4343      0.089      4.866      0.000       0.259       0.609
# ...

# %%
df2['forecast'] = model_fit.predict(start=90,end=103,dynamic=True)
df2[['Sales','forecast']].plot(figsize=(12,8))
# Out:
# <AxesSubplot:>

# %%
# ARIMA does not preform well

# %%
import statsmodels.api as sm

# %%
model = sm.tsa.statespace.SARIMAX(df2['Sales'],order=(1, 1, 1),seasonal_order=(1,1,1,12)) #p,d,q values
results = model.fit()

# %%
df2['forecast'] = results.predict(start=90,end=103,dynamic=True)
df2[['Sales','forecast']].plot(figsize=(12,8))
# Out:
# <AxesSubplot:>

# %%
df2
# Out:
#          Month   Sales  Sales First Difference  Seasonal First Difference  \
# 0   1964-01-01  2815.0                     NaN                        NaN
# 1   1964-02-01  2672.0                  -143.0                        NaN
# 2   1964-03-01  2755.0                    83.0                        NaN
# 3   1964-04-01  2721.0                   -34.0                        NaN
# 4   1964-05-01  2946.0                   225.0                        NaN
# ..         ...     ...                     ...                        ...
# 100 1972-05-01  4618.0                  -170.0                     -392.0
# 101 1972-06-01  5312.0                   694.0                      438.0
# 102 1972-07-01  4298.0                 -1014.0                     -335.0
# 103 1972-08-01  1413.0                 -2885.0                     -246.0
# 104 1972-09-01  5877.0                  4464.0                      -74.0
#
#         forecast
# 0            NaN
# 1            NaN
# 2            NaN
# ...

# %%
from pandas.tseries.offsets import DateOffset
#df2.iloc[104,0]
future_dates = ['1972-10','1972-11','1972-12','1973-01','1973-02','1973-03','1973-04','1973-05','1973-06','1973-07'
                ,'1973-08','1973-09','1973-10','1973-11','1973-12','1974-01','1974-02','1974-03','1974-04','1974-05'
               ,'1974-06','1974-07','1974-08']
future_dates = pd.to_datetime(future_dates)
indexes = [x for x in range(105,127)]

# %%
#future_dates = [df2.iloc[104,0]+ DateOffset(months=x)for x in range(0,24)]

# %%
#[DateOffset(months = x) for x in range(0,24)]

# %%
for index in indexes:
    df2.loc[index] = [future_dates[index-105],'NaN','NaN','NaN','NaN']

# %%
df2
# Out:
#          Month   Sales  Sales First Difference  Seasonal First Difference  \
# 0   1964-01-01  2815.0                     NaN                        NaN
# 1   1964-02-01  2672.0                  -143.0                        NaN
# 2   1964-03-01  2755.0                    83.0                        NaN
# 3   1964-04-01  2721.0                   -34.0                        NaN
# 4   1964-05-01  2946.0                   225.0                        NaN
# ..         ...     ...                     ...                        ...
# 122 1974-03-01     NaN                     NaN                        NaN
# 123 1974-04-01     NaN                     NaN                        NaN
# 124 1974-05-01     NaN                     NaN                        NaN
# 125 1974-06-01     NaN                     NaN                        NaN
# 126 1974-07-01     NaN                     NaN                        NaN
#
#      forecast
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# ...

# %%
#future_df = pd.concat([df2,future_datest_df])
#future_df

# %%
df2['forecast'] = results.predict(start = 104, end = 120, dynamic= True)  
df2[['Sales', 'forecast']].plot(figsize=(12, 8))
# Out:
# <AxesSubplot:>
